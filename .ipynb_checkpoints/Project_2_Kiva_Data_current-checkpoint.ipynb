# %% [markdown]
# # Imports
#
# from bs4 import BeautifulSoup
# import requests
# import datetime
# import time
# import pandas as pd
# import numpy as np
# import json
# import re
# from pprint import pprint
# import csv
# import pickle
# import warnings
# warnings.filterwarnings('ignore')

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import patsy
from textatistic import Textatistic
from textblob import TextBlob

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV
from sklearn import metrics
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline
from sklearn import cross_validation
from sklearn.cross_validation import train_test_split
from sklearn.cross_validation import KFold
from sklearn.cross_validation import cross_val_score
from sklearn.linear_model import LassoCV
from sklearn.linear_model import RidgeCV

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objs as go 
from plotly.offline import init_notebook_mode,iplot
init_notebook_mode(connected=True) 
# %matplotlib inline
sns.set_style(style='darkgrid')
plt.rcParams["patch.force_edgecolor"]=True
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# # Full Dataset

# %%
#read in the large 1.4 million entry csv file.
kiva_big = pd.read_csv('/Users/travis/Downloads/kiva_ds_csv/loans.csv')
#kiva_big = pd.read_json('/Users/travis/Downloads/kiva_ds_json/loans.json')

# %%
#find places without a translated description and copy over the original so I can drop the description column
kiva_big.DESCRIPTION_TRANSLATED.fillna(kiva_big.DESCRIPTION, inplace=True)

# %%
#Drop rows where there is no description
kiva_big.dropna(axis=0, how='any', subset=['DESCRIPTION'], inplace=True)

# %%
kiva_big.drop(['LOAN_NAME', 'DESCRIPTION', 'NUM_JOURNAL_ENTRIES',
               'NUM_BULK_ENTRIES', 'LOAN_USE','BORROWER_NAMES',
               'BORROWER_PICTURED','VIDEO_ID'],
             axis=1,
             inplace=True)

kiva_big.drop(['CURRENCY'], axis=1, inplace=True)

kiva_big.drop(['CURRENCY_EXCHANGE_COVERAGE_RATE'], axis=1, inplace=True)

kiva_big.drop(['COUNTRY_CODE'], axis=1, inplace=True)

kiva_big.drop(['NUM_LENDERS_TOTAL'], axis=1, inplace=True)

kiva_big.drop(['ACTIVITY_NAME'], axis=1, inplace=True)

# %%
#this gives me percent of rows that have 'TAGS' as null. 55%, keeping this column, can turn into categorical (either yes/no) and use for testing
kiva_big['TAGS'].isnull().mean()
# Out:
# 0.5491171397391017

# %%
kiva_big['PARTNER_ID']

# %%
kiva_big.to_pickle('kiva_full.pkl')

# %%
#len(re.findall(r'\w+', kiva_big['DESCRIPTION'][1]))

# %%
# with pd.option_context('display.max_rows', None, 'display.max_columns', None):
#    display(kiva_big.head(1))

# %%
#find values where it is direct funding and the loan either did not receive full funding or is actively fundraising
kiva_big[(kiva_big['LOAN_AMOUNT'] > kiva_big['FUNDED_AMOUNT']) & (kiva_big['DISTRIBUTION_MODEL'] == 'direct')]

# %% [markdown]
# ## outdated, ignore

# %% [markdown]
# tried to use this to load the Json, it did not work and just ran my computer into the ground.
# ```python
# max_records = 1e5
# df = pd.read_json(file, lines=True, chunksize=max_records)
# filtered_data = pd.DataFrame()
# try:
#     for df_chunk in df:
#         filtered_data = pd.concat([filtered_data, df_chubnk])
# except ValueError:
#     print('\nData Cannot be Parsed')
# ```

# %%
#outdated
#kiva_full.drop(['ORIGINAL_LANGUAGE', 'DESCRIPTION_TRANSLATED',
#           'IMAGE_ID', 'VIDEO_ID', 'TOWN_NAME', 'TAGS', 'BORROWER_NAMES',
#           'BORROWER_PICTURED', 'LOAN_USE', 'COUNTRY_CODE'],
#          axis=1,
#          inplace=True)

# %% [markdown]
# # Creating 50K Sample

# %%
kiva = kiva_big.sample(50000)

# %%
kiva = kiva.reset_index()

# %%
kiva.drop('index', axis=1, inplace=True)

# %%
#kiva.to_pickle('kiva_423.pkl')

# %%
kiva['DISBURSE_TIME'] = pd.to_datetime(kiva['DISBURSE_TIME'])
kiva['PLANNED_EXPIRATION_TIME'] = pd.to_datetime(kiva['PLANNED_EXPIRATION_TIME'])
kiva['RAISED_TIME'] = pd.to_datetime(kiva['RAISED_TIME'])
kiva['POSTED_TIME'] = pd.to_datetime(kiva['POSTED_TIME'])

# %%
kiva['TIME_DELTA'] = kiva['RAISED_TIME'] - kiva['POSTED_TIME']

# %%
#run to create a days column of number of days it takes a project to get funding.
kiva['DAYS_TO_FUND'] = kiva['TIME_DELTA']/np.timedelta64(1,'D')

# %%
#ensure that the timedelta for Days is a value greater than 0
def cleanDays(row):
    a = row.DAYS_TO_FUND
    if a<0:
        return np.nan
    else:
        return a

# %%
#apply the function cleanDays to the dataframe reassigning negative values to nan. Time must pass forward!
#run when first creating the days column
kiva['DAYS_TO_FUND'] = kiva.apply(cleanDays, axis=1)

# %%
#I found errors in the date posted column, that come with the initial csv.
#I cannot identify those without searching 1x1. but kiva has an upper limit on funding periods
#So anything beyond 60 days I set to nan to catch those errors (less than .5% of this sample is effected)
#This is not guaranteed to catch all errors of this type, but it catches many
#if length of time to get funding is more than 60 days, convert to nan
kiva['DAYS_TO_FUND'][kiva['DAYS_TO_FUND'] >=60] = np.nan

# %%
def clean_log_funded(row):
    a = row.LOG_FUNDED
    if a<0:
        return np.nan
    else:
        return a

# %%
#run to scale the funding amount by log and drop null values
kiva['LOG_FUNDED'] = np.log(kiva['FUNDED_AMOUNT'].dropna())
#run to clean LOG_FUNDED column
kiva['LOG_FUNDED'] = kiva.apply(clean_log_funded, axis=1)

# %%
#create columnns of number of female borrowers and male borrowers per loan and total number of borrowers
kiva['FEMALE_BORROWERS'] = kiva['BORROWER_GENDERS'].str.title().str.count('Female')
kiva['MALE_BORROWERS'] = kiva['BORROWER_GENDERS'].str.title().str.count('Male')
kiva['BORROWERS_TOTAL'] = kiva['FEMALE_BORROWERS'] + kiva['MALE_BORROWERS']
kiva['PRIMARY_GENDER'] = kiva['FEMALE_BORROWERS'] - kiva['MALE_BORROWERS']

# %%
#Extracts the year from the year the loan request was posted
kiva['YEAR'] = kiva['POSTED_TIME'].dt.year

# %%
#Create a column of the month posted, to see if things fund faster in different times of year
kiva['MONTH'] = kiva['POSTED_TIME'].dt.month

# %%
#Set Primary gender to 1 if there are more female borrowers than male borrowers
kiva['PRIMARY_GENDER'][(kiva['FEMALE_BORROWERS'] - kiva['MALE_BORROWERS'] >=0)] = 'Female'
kiva['PRIMARY_GENDER'][((kiva['FEMALE_BORROWERS'] - kiva['MALE_BORROWERS']) <0)] = 'Male'

# %%
kiva['PERCENT_FEMALE']= (kiva['FEMALE_BORROWERS'] / kiva['BORROWERS_TOTAL'])

# %%
kiva['PERCENT_FEMALE_GROUPED'] = 0

# %%
#break into clusters
kiva['PERCENT_FEMALE_GROUPED'][(kiva['PERCENT_FEMALE'] == 0)] = 0
kiva['PERCENT_FEMALE_GROUPED'][(kiva['PERCENT_FEMALE'] > 0) & (kiva['PERCENT_FEMALE'] <=.33)] = .25
kiva['PERCENT_FEMALE_GROUPED'][(kiva['PERCENT_FEMALE'] > .33) & (kiva['PERCENT_FEMALE'] <=.66)] = .5
kiva['PERCENT_FEMALE_GROUPED'][(kiva['PERCENT_FEMALE'] > .66) & (kiva['PERCENT_FEMALE'] <=.99)] = .75
kiva['PERCENT_FEMALE_GROUPED'][(kiva['PERCENT_FEMALE'] > .99) & (kiva['PERCENT_FEMALE'] <=1)] = 1

# %%
#convert partnerid column to strings since I want them as categorical data, not numeric
kiva['PARTNER_ID'] = kiva['PARTNER_ID'].apply(str)

# %%
#replace null values in description column with empty strings
kiva['DESCRIPTION_TRANSLATED'] = kiva['DESCRIPTION_TRANSLATED'].fillna('')

# %%
kiva['HAS_TAGS'] = 0
kiva['HAS_TAGS'][kiva['TAGS'].isnull() == True] = 0
kiva['HAS_TAGS'][kiva['TAGS'].isnull() == False] = 1

# %%
#create new column with length of description (word count)
kiva['LEN_DESC'] = kiva['DESCRIPTION_TRANSLATED'].apply(lambda x: len(re.findall(r'\w+', x)))

# %%
kiva['SQRT_DAYS'] = np.sqrt(kiva['DAYS_TO_FUND'])

# %%
def flesch_read(x):
    try:
        s=Textatistic(x)
        return s.flesch_score
    except: return np.nan

# %%
#calculate Flesch Score for descriptions
kiva['FLESCH_SCORE'] = kiva['DESCRIPTION_TRANSLATED'].apply(lambda x: flesch_read(x))

# %%
#Create subset that is just loans that received funding.
kiva2 = kiva[kiva['STATUS'] == 'funded']

# %%
kiva2 = kiva2[kiva2['BORROWERS_TOTAL'].isnull() ==False]

# %%
kiva2 = kiva2[kiva2['DAYS_TO_FUND'].isnull() == False]

# %%
kiva = pd.read_pickle('kiva_423.pkl')

# %% [markdown]
# # Breaking into Country Data

# %%
#kiva2.nsmallest(15, 'DAYS')
# Out:
#        LOAN_ID ORIGINAL_LANGUAGE  \
# 0       187708           English
# 1      1334553           English
# 2       739463           English
# 3      1287169           Spanish
# 4       490283           Spanish
# 5       298472           Spanish
# 6       754293           English
# 7       363021           Spanish
# 8       260440           English
# 10       35418           English
# 11      956749           English
# 12      450526           English
# 13      714591           English
# 14      586272           English
# 15      728656           English
# 16      228483           Spanish
# 17      697774           English
# 18     1367051           English
# 19     1330741           English
# 20     1409137           Spanish
# 21     1372870           Spanish
# 22     1056120           English
# 24      140727           Spanish
# 25     1247119           English
# 26      966777           English
# 27      496763           English
# 28     1333165            French
# 29       62367           English
# 30      660923           English
# 31     1246510           English
# ...        ...               ...
# 49969   844714           English
# 49970  1114249           English
# 49971   290220           Spanish
# 49972  1414990           English
# 49973   176387           English
# 49974   341443            French
# 49975   579694            French
# 49976   350650           Spanish
# 49977  1409644           English
# 49978   620210           English
# 49979  1221038           Spanish
# 49980   940153           English
# 49981   601403           Spanish
# 49982  1409935           English
# 49983   703837           Spanish
# 49984  1047919           English
# 49986  1052982           English
# 49987   313910           English
# 49988   938408           Spanish
# 49989  1420479           Spanish
# 49990   684747           English
# 49991   534445            French
# 49992   636201           English
# 49993  1133107           Russian
# 49994  1091118           English
# 49995   397501           English
# 49996   505739           Spanish
# 49997    74060           English
# 49998  1056006           Spanish
# 49999   483549           Spanish
#
#                                   DESCRIPTION_TRANSLATED  FUNDED_AMOUNT  \
# 0      Mary is successful and hardworking. She is 45 ...          950.0
# 1      Lecyl is 30 years old, married and has 2 child...          300.0
# 2       Mrs. Sau is 50 years old .There are five peop...          500.0
# 3      La Sequita belongs to Montecristi, a prosperou...          875.0
# 4      Reyna is single with a nuclear family of four,...         1100.0
# 5      Alba Esperanza, age 64, has maintained a good ...          225.0
# 6      This is Cherie, 28, a resident of Pontevedra, ...          475.0
# 7      Esperanza Adelina has a grocery store which sh...          425.0
# 8      Dieu Donne is 32 years old and is single. Dieu...          850.0
# 10     Katebo business group is located in the Katebo...         4175.0
# 11     As a married parent of three children, Joy wor...          250.0
# 12     Wycklyne is twenty nine years old and married....          375.0
# 13     Marie Lee is 40 years old and lives in Salimpo...          250.0
# 14     Rana was born in 1989. She is single and lives...          600.0
# 15     Estrella is a hardworking entrepreneur who has...          475.0
# 16     Bajos de Montecristi is a place known for its ...          625.0
# 17     Widjai is 28 years old and lives with his pare...         3100.0
# 18     YOEUN’s Group lives in a rural village in Kand...          100.0
# 19     Daniel is 37 years old. He is married to Joyce...          200.0
# 20     The member, Elsa, belongs to the "Señor de Acc...          600.0
# 21     Maria Esther lives to the east of the city of ...          400.0
# 22     Erlyn is 38 years old and single. She runs a g...          225.0
# 24           El señor Jesús Antonio C. es padre de fa...          525.0
# 25     Kadiatu is the featured leader of this group o...          350.0
# 26     Srey’s group lives in a rural village in the P...          100.0
# 27     Mary has operated her second-hand clothing sal...          375.0
# 28     Akofa, 33 years-old, is a married woman who li...          450.0
# 29     This 46-year-old man is Abdul J..  He is marri...          650.0
# 30     Aida is married with three children. She has a...          825.0
# 31     Sopheap is 37 years old. She is a beloved moth...          750.0
# ...                                                  ...            ...
# 49969  Reyzel is a hardworking entrepreneur who has a...          425.0
# 49970  Sarem is 39 year old. She is a grocery seller,...          300.0
# 49971  Olga is 30 years old and a native of the distr...          725.0
# 49972  Jakuben is a 42-year-old married woman hailing...          400.0
# 49973  Anabell sells electronics at the market in Lag...         1000.0
# 49974  Adjowa is 27 years old and married to a nurse....          625.0
# 49975  The members of this group called BENKADI 2 are...          700.0
# 49976  Robert is a 41-year-old man who lives with his...         1000.0
# 49977  Evaline is now 39 years old very grateful for ...          500.0
# 49978  Rebeccah is a single woman. She has three chil...          250.0
# 49979  Mery is 22 years old and the single mother of ...          500.0
# 49980  Running a variety store is a common enterprise...          225.0
# 49981  Maria is a young woman who is 23 years of age....          700.0
# 49982  This is 23-year-old Tetama. She is a single mo...          300.0
# 49983  Maicol was born in Lima, Peru, and lives in th...         7500.0
# 49984  Saroem’s group lives in a rural village in Tak...          125.0
# 49986  The lady standing to the extreme left-hand sid...          700.0
# 49987  Cleophas is 39 years old, married, and has thr...          250.0
# 49988  José, who is 25 years old and lives in Olanchi...          750.0
# 49989  Martha is an enterprising woman. She is 38 yea...          825.0
# 49990  Dadee is a 36-year-old lady living in the Sink...          150.0
# 49991  Assane is 24 years old, single and has no chil...          200.0
# 49992  Christian is an entrepreneur in Ishaka town de...          800.0
# 49993  Ra’no is a 27-year-old woman from the Tursun-z...         1000.0
# 49994  I was born in Dessie, Ethiopia and was raised ...         2500.0
# 49995  Virgilio is married with three children. Virgi...          175.0
# 49996  The borrower is continuing to sell comforters ...         1175.0
# 49997  Rose A. is a 56-year-old divorced mother of tw...          425.0
# 49998  Ilce is a girl who likes helping others and th...          825.0
# 49999  Canelita Communal Bank will start its second l...         4175.0
#
#        LOAN_AMOUNT  STATUS   IMAGE_ID     SECTOR_NAME   COUNTRY_NAME  \
# 0            950.0  funded   512106.0            Food        Nigeria
# 1            300.0  funded  2577037.0            Food    Philippines
# 2            500.0  funded  1649235.0         Housing        Vietnam
# 3            875.0  funded  2510183.0          Retail        Ecuador
# 4           1100.0  funded  1226266.0          Retail      Nicaragua
# 5            225.0  funded   769461.0  Transportation      Nicaragua
# 6            475.0  funded  1672246.0          Retail    Philippines
# 7            425.0  funded   928864.0          Retail      Nicaragua
# 8            850.0  funded   666891.0            Arts         Rwanda
# 10          4175.0  funded   126545.0     Agriculture         Uganda
# 11           250.0  funded  1991878.0          Retail    Philippines
# 12           375.0  funded  1142770.0            Food          Kenya
# 13           250.0  funded  1610397.0          Retail    Philippines
# 14           600.0  funded  1392634.0        Clothing         Jordan
# 15           475.0  funded  1631995.0     Agriculture    Philippines
# 16           625.0  funded   594551.0            Food        Ecuador
# 17          3100.0  funded  1584002.0     Agriculture       Suriname
# 18           100.0  funded  2621776.0    Personal Use       Cambodia
# 19           200.0  funded  2562230.0     Agriculture          Kenya
# 20           600.0  funded  2682289.0            Arts           Peru
# 21           400.0  funded  2628406.0          Health         Mexico
# 22           225.0  funded  2155673.0          Retail    Philippines
# 24           525.0  funded   396423.0         Housing         Mexico
# 25           350.0  funded  2453452.0            Food   Sierra Leone
# 26           100.0  funded  2004798.0    Personal Use       Cambodia
# 27           375.0  funded  1236911.0        Clothing          Kenya
# 28           450.0  funded  2575457.0          Retail           Togo
# 29           650.0  funded   195082.0     Agriculture    Afghanistan
# 30           825.0  funded  1516741.0          Retail         Uganda
# 31           750.0  funded  2452770.0     Agriculture       Cambodia
# ...            ...     ...        ...             ...            ...
# 49969        425.0  funded  1821367.0          Retail    Philippines
# 49970        300.0  funded  2249807.0    Personal Use       Cambodia
# 49971        725.0  funded   750427.0     Agriculture           Peru
# 49972        400.0  funded  2690217.0     Agriculture          India
# 49973       1000.0  funded   489421.0          Retail        Nigeria
# 49974        625.0  funded   883798.0          Retail           Togo
# 49975        700.0  funded  1383132.0     Agriculture           Mali
# 49976       1000.0  funded   903036.0     Agriculture     Costa Rica
# 49977        500.0  funded  2673378.0       Education          Kenya
# 49978        250.0  funded  1451802.0          Retail          Kenya
# 49979        500.0  funded  2417749.0     Agriculture        Ecuador
# 49980        225.0  funded  1967303.0          Retail    Philippines
# 49981        700.0  funded  1420431.0       Education       Paraguay
# 49982        300.0  funded  2683459.0            Food        Liberia
# 49983       7500.0  funded  1595134.0       Education           Peru
# 49984        125.0  funded  2132502.0    Personal Use       Cambodia
# 49986        700.0  funded  2148280.0       Education          India
# 49987        250.0  funded   806134.0    Construction          Kenya
# 49988        750.0  funded  1964664.0    Personal Use       Honduras
# 49989        825.0  funded  2698100.0            Food      Nicaragua
# 49990        150.0  funded  1560670.0            Food        Liberia
# 49991        200.0  funded  1306066.0            Food        Senegal
# 49992        800.0  funded  1475858.0         Housing         Uganda
# 49993       1000.0  funded  2275905.0        Services     Tajikistan
# 49994       2500.0  funded  2209938.0        Services  United States
# 49995        175.0  funded  1010440.0     Agriculture    Philippines
# 49996       1175.0  funded  1166154.0          Retail           Peru
# 49997        425.0  funded   224712.0            Food          Ghana
# 49998        825.0  funded  2155494.0       Education      Nicaragua
# 49999       4175.0  funded  1215243.0            Food        Bolivia
#
#                                            TOWN_NAME   ...    BORROWERS_TOTAL  \
# 0                                        Lagos State   ...                  1
# 1                   Bitibut, Sapang dalaga, Mis. Occ   ...                  1
# 2                             Quang Ninh, Quang Binh   ...                  1
# 3                                        Montecristi   ...                  1
# 4                                             Masaya   ...                  1
# 5                                               Leon   ...                  1
# 6                                  Pontevedra, Capiz   ...                  1
# 7                                               Leon   ...                  1
# 8                                             Kigali   ...                  1
# 10                                            Buwama   ...                 18
# 11                                 Roxas City, Capiz   ...                  1
# 12                               Kawangware, Nairobi   ...                  1
# 13     Jimenez-Salimpono, Panaon, Misamis Occidental   ...                  1
# 14                                             Karak   ...                  1
# 15                                  Compostela, Cebu   ...                  1
# 16                                        Portoviejo   ...                  1
# 17                                          Nickerie   ...                  1
# 18                                            Kandal   ...                  2
# 19                                   Nyandarua South   ...                  1
# 20                             Pisac - Calca - Cusco   ...                  1
# 21                                         Monterrey   ...                  1
# 22                           Tanjay, Negros Oriental   ...                  1
# 24                                               NaN   ...                  1
# 25                                            Kabala   ...                  5
# 26                                            Kandal   ...                  2
# 27                                            Kilifi   ...                  1
# 28                                         Adidogomé   ...                  1
# 29                                         Jalalabad   ...                  1
# 30                                           Kampala   ...                  1
# 31                                      Kampong Speu   ...                  1
# ...                                              ...   ...                ...
# 49969                  Himamaylan, Negros Occidental   ...                  1
# 49970                                Kampong Chhnang   ...                  1
# 49971                                       Ayacucho   ...                  1
# 49972                                  Surendranagar   ...                  1
# 49973                                    Lagos State   ...                  1
# 49974                                           Lomé   ...                  1
# 49975                                         Tibina   ...                  6
# 49976                                     Puntarenas   ...                  1
# 49977                                       Kapsabet   ...                  1
# 49978                                         Nakuru   ...                  1
# 49979                                    San Gabriel   ...                  1
# 49980            General Santos City, South Cotabato   ...                  1
# 49981                                          CHACO   ...                  1
# 49982                                       Caldwell   ...                  1
# 49983                                           Lima   ...                  1
# 49984                                          Takeo   ...                  3
# 49986                               Nayagarh, Odisha   ...                  3
# 49987                                       Kakamega   ...                  1
# 49988                                      Olanchito   ...                  1
# 49989                                        Managua   ...                  1
# 49990                                         Sinkor   ...                  1
# 49991                                            NaN   ...                  1
# 49992                                         Ishaka   ...                  1
# 49993                                    Tursun-zoda   ...                  1
# 49994                                            NaN   ...                  1
# 49995    Jimenez-Mialem, Jimenez, Misamis Occidental   ...                  2
# 49996                                          Cusco   ...                  1
# 49997                                           Tema   ...                  1
# 49998                                           Leon   ...                  1
# 49999                              La Paz  / El Alto   ...                 11
#
#       PRIMARY_GENDER  YEAR Month PERCENT_FEMALE PERCENT_FEMALE_GROUPED  \
# 0             Female  2010     3       1.000000                   1.00
# 1             Female  2017     7       1.000000                   1.00
# 2             Female  2014     7       1.000000                   1.00
# 3             Female  2017     4       1.000000                   1.00
# 4             Female  2012    10       1.000000                   1.00
# 5             Female  2011     5       1.000000                   1.00
# 6             Female  2014     8       1.000000                   1.00
# 7             Female  2011    11       1.000000                   1.00
# 8               Male  2010    12       0.000000                   0.00
# 10              Male  2008     2       0.388889                   0.50
# 11            Female  2015    10       1.000000                   1.00
# 12            Female  2012     7       1.000000                   1.00
# 13            Female  2014     5       1.000000                   1.00
# 14            Female  2013     7       1.000000                   1.00
# 15            Female  2014     6       1.000000                   1.00
# 16            Female  2010     9       1.000000                   1.00
# 17              Male  2014     4       0.000000                   0.00
# 18            Female  2017     8       1.000000                   1.00
# 19              Male  2017     6       0.000000                   0.00
# 20            Female  2017    11       1.000000                   1.00
# 21            Female  2017     9       1.000000                   1.00
# 22            Female  2016     4       1.000000                   1.00
# 24              Male  2009     9       0.000000                   0.00
# 25            Female  2017     2       1.000000                   1.00
# 26            Female  2015    10       0.500000                   0.50
# 27            Female  2012    11       1.000000                   1.00
# 28            Female  2017     7       1.000000                   1.00
# 29              Male  2008     8       0.000000                   0.00
# 30            Female  2014     1       1.000000                   1.00
# 31            Female  2017     2       1.000000                   1.00
# ...              ...   ...   ...            ...                    ...
# 49969         Female  2015     2       1.000000                   1.00
# 49970         Female  2016     7       1.000000                   1.00
# 49971         Female  2011     4       1.000000                   1.00
# 49972         Female  2017    11       1.000000                   1.00
# 49973         Female  2010     2       1.000000                   1.00
# 49974         Female  2011     9       1.000000                   1.00
# 49975         Female  2013     7       1.000000                   1.00
# 49976           Male  2011    10       0.000000                   0.00
# 49977         Female  2017    11       1.000000                   1.00
# 49978         Female  2013    10       1.000000                   1.00
# 49979         Female  2017     1       1.000000                   1.00
# 49980         Female  2015     8       1.000000                   1.00
# 49981         Female  2013     8       1.000000                   1.00
# 49982         Female  2017    11       1.000000                   1.00
# 49983           Male  2014     4       0.000000                   0.00
# 49984           Male  2016     4       0.333333                   0.50
# 49986         Female  2016     4       1.000000                   1.00
# 49987           Male  2011     7       0.000000                   0.00
# 49988           Male  2015     8       0.000000                   0.00
# 49989         Female  2017    11       1.000000                   1.00
# 49990         Female  2014     3       1.000000                   1.00
# 49991           Male  2013     3       0.000000                   0.00
# 49992           Male  2013    11       0.000000                   0.00
# 49993         Female  2016     8       1.000000                   1.00
# 49994         Female  2016     4       1.000000                   1.00
# 49995         Female  2012     2       0.500000                   0.50
# 49996         Female  2012    12       1.000000                   1.00
# 49997         Female  2008    11       1.000000                   1.00
# 49998         Female  2016     4       1.000000                   1.00
# 49999         Female  2012    10       0.909091                   0.75
#
#        LEN_DESC SQRT_DAYS FLESCH_SCORE HAS_TAGS
# 0            96  5.333940    78.912022        0
# 1            76  2.824342    75.894000        1
# 2           116  2.516457    81.423704        0
# 3           144  2.054805    83.264406        0
# 4           200  5.560569    78.340000        0
# 5            83  1.878774    73.000532        0
# 6           316  3.389791    67.283462        1
# 7            68  5.545472    86.036882        0
# 8           119  3.331187    73.354746        0
# 10           96  2.066381    86.283750        0
# 11          106  1.602440    74.221146        0
# 12           95  3.097746    81.595455        0
# 13          126  5.111358    77.344934        0
# 14           98  2.912712    89.254699        0
# 15           96  5.197857    65.031626        1
# 16          248  1.434814    76.621094        0
# 17           95  1.894061    89.979690        1
# 18           63  0.645076    69.660565        1
# 19           73  4.701216    88.819000        1
# 20           76  3.726587    71.530965        0
# 21          150  3.167699    80.079750        1
# 22           73  3.033282    71.999249        1
# 24           93  1.593596    74.942220        0
# 25          109  3.126104    77.331667        1
# 26           76  1.745653    70.491750        1
# 27          151  1.328062    78.561767        0
# 28           65  6.073148    81.012019        1
# 29          224  0.988428    84.207955        0
# 30          121  2.496416    77.878889        1
# 31          165  2.929835    80.793736        1
# ...         ...       ...          ...      ...
# 49969       101  5.243985    70.565776        1
# 49970       201  2.507357    86.716788        1
# 49971       243  1.827351    77.181860        0
# 49972       112  0.871162    77.599743        1
# 49973        92  1.165044    87.943088        0
# 49974        83  4.883058    87.551667        0
# 49975       168  4.810491    71.498896        0
# 49976       222  5.013183    65.663387        0
# 49977        65  1.871237    78.810000        1
# 49978       127  2.728633    78.732273        0
# 49979        80  0.345875    80.496734        1
# 49980       232  1.780284    65.787438        0
# 49981       112  1.976749    77.938333        0
# 49982       174  3.593497    90.634051        1
# 49983       155  5.085904    66.436529        1
# 49984        71  4.334013    73.049643        1
# 49986       222  2.330623    75.670615        1
# 49987        94  2.126739    74.865909        0
# 49988       290  3.135442    56.560560        1
# 49989        50  1.789815    82.475500        1
# 49990       105  1.146896    92.507143        0
# 49991       103  5.207372    77.401000        1
# 49992       237  6.293094    77.839229        1
# 49993       104  5.856910    91.096972        1
# 49994       175  6.056446    76.311337        0
# 49995       109  1.669848    80.501222        0
# 49996        92  2.552461    80.640964        0
# 49997       219  1.810291    71.781579        0
# 49998       108  2.384996    84.381667        1
# 49999       231  3.542382    68.155866        0
#
# [47454 rows x 36 columns]

# %%
#Loans with NaN values for language/description/image/etc are funded loans that have been made anonymous by Kiva
#They are real data points, but hard to capture as part of data set because of limited data available on them.
#Country, Funded Amount, Time to Fund, Dates, Partner_ID, and Tags
#I will run regressions with these included and not.

with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(kiva2[kiva2['ORIGINAL_LANGUAGE'].isnull()])
# Out:
# Empty DataFrame
# Columns: [LOAN_ID, ORIGINAL_LANGUAGE, DESCRIPTION_TRANSLATED, FUNDED_AMOUNT, LOAN_AMOUNT, STATUS, IMAGE_ID, SECTOR_NAME, COUNTRY_NAME, TOWN_NAME, CURRENCY_POLICY, PARTNER_ID, POSTED_TIME, PLANNED_EXPIRATION_TIME, DISBURSE_TIME, RAISED_TIME, LENDER_TERM, TAGS, BORROWER_GENDERS, REPAYMENT_INTERVAL, DISTRIBUTION_MODEL, TIME_DELTA, DAYS_TO_FUND, LOG_FUNDED, FEMALE_BORROWERS, MALE_BORROWERS, BORROWERS_TOTAL, PRIMARY_GENDER, YEAR, Month, PERCENT_FEMALE, PERCENT_FEMALE_GROUPED, LEN_DESC, SQRT_DAYS, FLESCH_SCORE, HAS_TAGS]
# Index: []

# %%
#create a plotly choropleth map of countries and the number of loans individuals there received 
counts = kiva2.COUNTRY_NAME.value_counts().reset_index()

counts.columns=['COUNTRY_NAME', 'COUNT']

counts['log_count'] = np.log(counts['COUNT'])

data = dict(type = 'choropleth',
             colorscale = 'Viridis',
            reversescale = True,
             locations = counts['COUNTRY_NAME'],
             locationmode = "country names",
             z = counts['log_count'],
             text = counts['COUNT'],
             colorbar = {'title':'Scaled Frequency'})

# %%
layout = dict(title = 'Kiva Loan Frequency Data',
             geo = dict(showframe = False,
                       projection = {'type':'Mercator'}))
choromap = go.Figure(data = [data],layout = layout)
iplot(choromap,validate=False)
# Out:
# <div id="fdd4ae1d-6480-4ff3-88da-854712bbd4ac" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("fdd4ae1d-6480-4ff3-88da-854712bbd4ac", [{"type": "choropleth", "colorscale": "Viridis", "reversescale": true, "locations": ["Philippines", "Kenya", "Peru", "Cambodia", "El Salvador", "Pakistan", "Uganda", "Tajikistan", "Nicaragua", "Ecuador", "Colombia", "Paraguay", "Bolivia", "Ghana", "Vietnam", "Nigeria", "Mexico", "Lebanon", "Samoa", "Honduras", "Sierra Leone", "Tanzania", "Togo", "Rwanda", "India", "Mali", "Senegal", "Guatemala", "Armenia", "Palestine", "Liberia", "Kyrgyzstan", "Indonesia", "Azerbaijan", "Mongolia", "Jordan", "Mozambique", "Georgia", "South Sudan", "Zimbabwe", "Madagascar", "United States", "Cameroon", "Ukraine", "Benin", "The Democratic Republic of the Congo", "Costa Rica", "Haiti", "Dominican Republic", "Timor-Leste", "Yemen", "Burkina Faso", "Egypt", "Albania", "Myanmar (Burma)", "Iraq", "Nepal", "Afghanistan", "Turkey", "Malawi", "Kosovo", "Lao People's Democratic Republic", "Burundi", "Solomon Islands", "Zambia", "Congo", "Lesotho", "Chile", "South Africa", "Moldova", "Bulgaria", "Israel", "Thailand", "Bosnia and Herzegovina", "Brazil", "Panama", "Cote D'Ivoire", "China", "Sri Lanka", "Suriname", "Puerto Rico", "Belize", "Somalia", "Guam"], "locationmode": "country names", "z": [9.230535079261703, 8.404248432400102, 7.99598047476376, 7.957877358489813, 7.577121930876679, 7.344072850573066, 7.284134806195205, 7.256297239690681, 7.226936018493289, 6.9865664594064265, 6.891625897052253, 6.78332520060396, 6.7357800142423265, 6.637258031284457, 6.6240652277998935, 6.5722825426940075, 6.568077911411976, 6.511745329644728, 6.3561076606958915, 6.289715570908998, 6.272877006546167, 6.269096283706261, 6.257667587882639, 6.246106765481563, 6.244166900663736, 6.126869184114185, 6.035481432524756, 6.023447592961033, 6.021023349349527, 6.003887067106539, 5.988961416889864, 5.950642552587727, 5.929589143389895, 5.771441123130016, 5.75890177387728, 5.755742213586912, 5.4510384535657, 5.429345628954441, 5.303304908059076, 5.204006687076795, 5.19295685089021, 5.176149732573829, 5.1647859739235145, 5.135798437050262, 5.111987788356544, 5.062595033026967, 5.049856007249537, 5.043425116919247, 4.962844630259907, 4.795790545596741, 4.787491742782046, 4.709530201312334, 4.574710978503383, 4.564348191467836, 4.564348191467836, 4.553876891600541, 4.442651256490317, 4.31748811353631, 4.23410650459726, 4.23410650459726, 4.204692619390966, 4.110873864173311, 3.912023005428146, 3.5553480614894135, 3.4965075614664802, 3.4011973816621555, 3.367295829986474, 3.367295829986474, 3.1780538303479458, 2.995732273553991, 2.5649493574615367, 2.5649493574615367, 2.5649493574615367, 2.4849066497880004, 2.4849066497880004, 2.1972245773362196, 2.1972245773362196, 2.0794415416798357, 2.0794415416798357, 2.0794415416798357, 1.6094379124341003, 1.3862943611198906, 1.3862943611198906, 0.0], "text": [10204, 4466, 2969, 2858, 1953, 1547, 1457, 1417, 1376, 1082, 984, 883, 842, 763, 753, 715, 712, 673, 576, 539, 530, 528, 522, 516, 515, 458, 418, 413, 412, 405, 399, 384, 376, 321, 317, 316, 233, 228, 201, 182, 180, 177, 175, 170, 166, 158, 156, 155, 143, 121, 120, 111, 97, 96, 96, 95, 85, 75, 69, 69, 67, 61, 50, 35, 33, 30, 29, 29, 24, 20, 13, 13, 13, 12, 12, 9, 9, 8, 8, 8, 5, 4, 4, 1], "colorbar": {"title": "Scaled Frequency"}}], {"title": "Kiva Loan Frequency Data", "geo": {"showframe": false, "projection": {"type": "Mercator"}}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
#find the 20 most frequent countries
df = kiva2.COUNTRY_NAME.value_counts().nlargest(20).reset_index()
df.columns=['COUNTRY_NAME','count']

# %%
df = kiva2.COUNTRY_NAME.value_counts().nlargest(20)
fig, axs = plt.subplots(1,1, figsize=(12,12))
f = plt.tight_layout()
df.plot.bar()

# %%
df = kiva2.SECTOR_NAME.value_counts()
fig, axs = plt.subplots(1,1, figsize=(12,12))
f = plt.tight_layout()
df.plot.bar()

# %%
big_countries = kiva2['COUNTRY_NAME'].value_counts().nlargest(20)
big_countries = big_countries.reset_index()
big_countries.columns=['COUNTRY_NAME', 'COUNT']
list_countries = big_countries['COUNTRY_NAME'].tolist()

# %%
df_agg = kiva2[kiva2['COUNTRY_NAME'].isin(list_countries)].groupby(['COUNTRY_NAME'])['SECTOR_NAME'].value_counts().unstack()
df_agg.plot(kind='bar', stacked=True, figsize=(16,16))

# %%
#viewing the correlation between days to funding and amount funded
sns.jointplot(x='DAYS_TO_FUND', y='FUNDED_AMOUNT', data=kiva2, kind='scatter')

# %%
#Same plot as above but log transformed funded amount, and sqrt transformed days
sns.jointplot(x='SQRT_DAYS', y='LOG_FUNDED', data=kiva2, kind='scatter')

# %%
#plot of how long it takes projects to get funded
fig = plt.subplots(1,1, figsize=(6,6))
fig = plt.xlim(0, 60)
fig = plt.xlabel("Days to get funded")
sns.distplot(kiva2['DAYS_TO_FUND'].dropna(), kde=False, bins = 100)

# %%
#plot of number of loans by size* size is scaled by log
fig = plt.subplots(1,1, figsize=(6,6))
fig = plt.xlim()
fig = plt.xlabel("Loan Size")
sns.distplot(kiva2['LOG_FUNDED'].dropna(), kde=False, bins = 50)

# %%
Kiva_Phil = kiva2[kiva2['COUNTRY_NAME']=='Philippines']

# %%
#mean_by_gender_phil = Kiva_Phil.drop(['LOAN_ID','LOAN_AMOUNT','LOG_FUNDED','FEMALE_BORROWERS','MALE_BORROWERS'], axis=1).groupby(['PRIMARY_GENDER','YEAR']).mean()

# %%
Kiva_Kenya[Kiva_Kenya['PRIMARY_GENDER'] == 'Female']
# Out:
#        LOAN_ID ORIGINAL_LANGUAGE  \
# 12      450526           English
# 27      496763           English
# 79      196343           English
# 87      915825           English
# 93     1059065           English
# 94     1104149           English
# 105    1335009           English
# 111     571998           English
# 133    1079867           English
# 138     357974           English
# 151     390872           English
# 154     826201           English
# 159    1430470           English
# 181     904758           English
# 194     346887           English
# 204    1085256           English
# 257    1352087           English
# 262     681223           English
# 274    1407470           English
# 297     354360           English
# 309     257289           English
# 402     638940           English
# 423    1231863           English
# 431     319774           English
# 436    1134038           English
# 441     497772           English
# 444     259829           English
# 449    1081202           English
# 468     941576           English
# 477     787831           English
# ...        ...               ...
# 49454   540095           English
# 49468  1010403           English
# 49482   604449           English
# 49483  1346450           English
# 49484  1107544           English
# 49521   473809           English
# 49546   793115           English
# 49594  1004544           English
# 49620   464979           English
# 49634  1158827           English
# 49639   675657           English
# 49692   846352           English
# 49697  1129262           English
# 49700   489301           English
# 49704  1397095           English
# 49714  1340489           English
# 49715  1088958           English
# 49781   793747           English
# 49802   362776           English
# 49809   717503           English
# 49817   337063           English
# 49822  1153957           English
# 49840   409884           English
# 49856   695489           English
# 49868   370743           English
# 49902  1080513           English
# 49930   547093           English
# 49951   982149           English
# 49977  1409644           English
# 49978   620210           English
#
#                                   DESCRIPTION_TRANSLATED  FUNDED_AMOUNT  \
# 12     Wycklyne is twenty nine years old and married....          375.0
# 27     Mary has operated her second-hand clothing sal...          375.0
# 79     Rose is a married woman with five children who...          275.0
# 87     Margret is a businesswoman based in Nairobi, t...          975.0
# 93     Janet is a married woman.  She has two childre...          300.0
# 94     Hannah is a 71 year-old lady.  She is married ...          300.0
# 105    Hello Kiva Community! <br /><br />Meet Pauline...          100.0
# 111    Fridah lives in the Nkubu area of Kenya, situa...          475.0
# 133    I was born in Kivu province in Democratic repu...          125.0
# 138    Mwanakura is 32 years and married to Hassan. S...          450.0
# 151    Pamela is a single mother and a farmer in the ...          375.0
# 154    Mariam is a married woman with three kids, all...          225.0
# 159    Lenah is a single woman. She has one child. Sh...          600.0
# 181    Gladys is a married woman who has six children...          325.0
# 194    Mwanasiti is a married woman with three school...          200.0
# 204    I grew up in Kiambu county at  the Outskirts o...          125.0
# 257    Beth, 50, is happily married and blessed with ...          500.0
# 262    Mildred is a 49-year-old woman from Usenge, ma...          125.0
# 274    Charity is a married woman. She has 3 children...          400.0
# 297    Florencia is a married woman with three childr...          325.0
# 309    Jerusha is a married woman with three children...          500.0
# 402    Elizabeth has had a grocery store in Kitengela...          175.0
# 423    Hello, Kiva Community! Meet Florah, a hardwork...           50.0
# 431    Elizabeth Masaga is 46 years old married to a ...          350.0
# 436    Susan is a married woman with one child who at...          500.0
# 441    A divorced mother who lives with her five chil...          125.0
# 444    Priscilla N. is 53 years old. She is single an...          125.0
# 449    I was born and raised in Mathare Nairobi Kenya...          125.0
# 468    Mwanajuma is married and a mother of two child...          400.0
# 477    Janet is a married woman; she has five childre...          575.0
# ...                                                  ...            ...
# 49454  Purity is a twenty-four year old mother of thr...         2000.0
# 49468  Monicah is a 47-year-old farmer from a remote ...          650.0
# 49482  Joan is a very hardworking and innovative woma...          350.0
# 49483  Basilisa is 33 years old. She is married and s...          300.0
# 49484  Naomi is a married mother of two children, bot...          500.0
# 49521  Saumu is a 48-year-old married woman who lives...           75.0
# 49546  Nachiro is a married woman, and she has three ...          400.0
# 49594  Miriam is married with seven children, two of ...          300.0
# 49620  Esther is 60 years old and married to Joseph. ...          250.0
# 49634  This is Winny - polite, devoted, responsible, ...          300.0
# 49639  Miriam, 23 years old, is from Nakuru. She is s...          125.0
# 49692  Pauline is a single woman. She has one child. ...          775.0
# 49697  Katunge is 55 years old, married, and blessed ...          200.0
# 49700  Mwanampikao sells fruits and vegetables. She i...          375.0
# 49704  Esther, 43, is happily married and blessed wit...          825.0
# 49714  Rodah is a smallholder farmer from Eldoret, in...          200.0
# 49715  I am a member of a JOYWO table banking group. ...          125.0
# 49781  Hello! Introducing Eunice, a 25-year-old mothe...          750.0
# 49802  Grace is the facilitator of the Malu A group. ...          900.0
# 49809  Hello!!! Meet Joyce a very hard working farmer...          475.0
# 49817  Leah is a married woman with one child who att...          225.0
# 49822  Perseverance, faith, honest work, and responsi...          200.0
# 49840  Violet is 46 years old. She is married with fo...          625.0
# 49856  Betty is a married woman with three children, ...          600.0
# 49868  Janet is 48 years old, married, and has three ...          350.0
# 49902  I grew up in Nyaani sub location- Muthetheni l...          375.0
# 49930  Mwanajuma has operated an open air food-sellin...          475.0
# 49951  Fenny is a married woman with six children, on...          500.0
# 49977  Evaline is now 39 years old very grateful for ...          500.0
# 49978  Rebeccah is a single woman. She has three chil...          250.0
#
#        LOAN_AMOUNT  STATUS   IMAGE_ID   SECTOR_NAME COUNTRY_NAME  \
# 12           375.0  funded  1142770.0          Food        Kenya
# 27           375.0  funded  1236911.0      Clothing        Kenya
# 79           275.0  funded   530573.0        Retail        Kenya
# 87           975.0  funded  1929035.0      Services        Kenya
# 93           300.0  funded  2160982.0          Food        Kenya
# 94           300.0  funded  2232471.0   Agriculture        Kenya
# 105          100.0  funded  2577649.0  Personal Use        Kenya
# 111          475.0  funded  1371066.0   Agriculture        Kenya
# 133          125.0  funded  2195511.0      Clothing        Kenya
# 138          450.0  funded   918492.0          Food        Kenya
# 151          375.0  funded  1003557.0   Agriculture        Kenya
# 154          225.0  funded  1790280.0          Food        Kenya
# 159          600.0  funded  2713643.0      Clothing        Kenya
# 181          325.0  funded  1909565.0          Food        Kenya
# 194          200.0  funded   895327.0      Clothing        Kenya
# 204          125.0  funded  2201359.0          Food        Kenya
# 257          500.0  funded  2601983.0   Agriculture        Kenya
# 262          125.0  funded  1549583.0        Retail        Kenya
# 274          400.0  funded  2679890.0   Agriculture        Kenya
# 297          325.0  funded   910656.0     Education        Kenya
# 309          500.0  funded   663325.0      Services        Kenya
# 402          175.0  funded  1477745.0          Food        Kenya
# 423           50.0  funded  2432817.0  Personal Use        Kenya
# 431          350.0  funded   819686.0        Retail        Kenya
# 436          500.0  funded  2279753.0        Retail        Kenya
# 441          125.0  funded  1238960.0          Food        Kenya
# 444          125.0  funded   671679.0          Food        Kenya
# 449          125.0  funded  2196977.0      Services        Kenya
# 468          400.0  funded  1965015.0          Food        Kenya
# 477          575.0  funded  1719974.0        Retail        Kenya
# ...            ...     ...        ...           ...          ...
# 49454       2000.0  funded  1311688.0   Agriculture        Kenya
# 49468        650.0  funded  2080933.0   Agriculture        Kenya
# 49482        350.0  funded  1425805.0     Education        Kenya
# 49483        300.0  funded  2585808.0   Agriculture        Kenya
# 49484        500.0  funded  2240089.0      Clothing        Kenya
# 49521         75.0  funded  1197497.0          Food        Kenya
# 49546        400.0  funded  1727242.0          Food        Kenya
# 49594        300.0  funded  2071536.0          Food        Kenya
# 49620        250.0  funded  1176258.0   Agriculture        Kenya
# 49634        300.0  funded  2320113.0   Agriculture        Kenya
# 49639        125.0  funded  1536702.0        Health        Kenya
# 49692        775.0  funded  1823452.0      Clothing        Kenya
# 49697        200.0  funded  2271396.0   Agriculture        Kenya
# 49700        375.0  funded  1224581.0          Food        Kenya
# 49704        825.0  funded  2663413.0          Food        Kenya
# 49714        200.0  funded  2585489.0   Agriculture        Kenya
# 49715        125.0  funded  2206167.0        Retail        Kenya
# 49781        750.0  funded  1728208.0   Agriculture        Kenya
# 49802        900.0  funded   928537.0   Agriculture        Kenya
# 49809        475.0  funded  1614552.0   Agriculture        Kenya
# 49817        225.0  funded   873039.0        Retail        Kenya
# 49822        200.0  funded  2312907.0   Agriculture        Kenya
# 49840        625.0  funded  1058806.0      Clothing        Kenya
# 49856        600.0  funded  1580626.0          Food        Kenya
# 49868        350.0  funded   947795.0   Agriculture        Kenya
# 49902        375.0  funded  2196237.0        Retail        Kenya
# 49930        475.0  funded   928785.0        Retail        Kenya
# 49951        500.0  funded  2029719.0        Retail        Kenya
# 49977        500.0  funded  2673378.0     Education        Kenya
# 49978        250.0  funded  1451802.0        Retail        Kenya
#
#                           TOWN_NAME   ...    BORROWERS_TOTAL PRIMARY_GENDER  \
# 12              Kawangware, Nairobi   ...                  1         Female
# 27                           Kilifi   ...                  1         Female
# 79                      Seven Hills   ...                  1         Female
# 87     Kwa Njenga, Mukuru, Nairobi.   ...                  1         Female
# 93                           Nakuru   ...                  1         Female
# 94                      Nakuru West   ...                  1         Female
# 105                           Thika   ...                  1         Female
# 111                           Nkubu   ...                  1         Female
# 133                             NaN   ...                  1         Female
# 138                       Msambweni   ...                  1         Female
# 151                           Nkubu   ...                  1         Female
# 154                          Tiribe   ...                  1         Female
# 159                           Kisii   ...                  1         Female
# 181                          Kisumu   ...                  1         Female
# 194                       Msambweni   ...                  1         Female
# 204                             NaN   ...                  1         Female
# 257                           nyeri   ...                  1         Female
# 262                   Usenge;Kisumu   ...                  1         Female
# 274                        karatina   ...                  1         Female
# 297                         Kisauni   ...                  1         Female
# 309                          Likoni   ...                  1         Female
# 402               Kitengela;Nairobi   ...                  1         Female
# 423                       Nyahururu   ...                  1         Female
# 431                  Kegonga;Migori   ...                  1         Female
# 436                       Msambweni   ...                  1         Female
# 441                       Msambweni   ...                  1         Female
# 444                        Kakamega   ...                  1         Female
# 449                             NaN   ...                  1         Female
# 468                          Likoni   ...                  1         Female
# 477                         Kisauni   ...                  1         Female
# ...                             ...   ...                ...            ...
# 49454              Mtsara wa Tsatsu   ...                  4         Female
# 49468                        Kitale   ...                  1         Female
# 49482                       Kisauni   ...                  1         Female
# 49483                      Kapsabet   ...                  1         Female
# 49484                     Msambweni   ...                  1         Female
# 49521                        Tiribe   ...                  1         Female
# 49546                       Mombasa   ...                  1         Female
# 49594                        Likoni   ...                  1         Female
# 49620               Kangemi,Nairobi   ...                  1         Female
# 49634                       Kericho   ...                  1         Female
# 49639                        Nakuru   ...                  1         Female
# 49692                        Nakuru   ...                  1         Female
# 49697                      Machakos   ...                  1         Female
# 49700                     Msambweni   ...                  1         Female
# 49704                    Githunguri   ...                  1         Female
# 49714                       Eldoret   ...                  1         Female
# 49715                           NaN   ...                  1         Female
# 49781                         Thika   ...                  1         Female
# 49802                        Webuye   ...                 10         Female
# 49809                        Litein   ...                  1         Female
# 49817                        Tiribe   ...                  1         Female
# 49822                        Litein   ...                  1         Female
# 49840                           NaN   ...                  1         Female
# 49856                       Kisauni   ...                  1         Female
# 49868                      Murang'a   ...                  1         Female
# 49902                           NaN   ...                  1         Female
# 49930                        Likoni   ...                  1         Female
# 49951                        Likoni   ...                  1         Female
# 49977                      Kapsabet   ...                  1         Female
# 49978                        Nakuru   ...                  1         Female
#
#        YEAR Month PERCENT_FEMALE PERCENT_FEMALE_GROUPED  LEN_DESC SQRT_DAYS  \
# 12     2012     7            1.0                    1.0        95  3.097746
# 27     2012    11            1.0                    1.0       151  1.328062
# 79     2010     4            1.0                    1.0       141  1.097050
# 87     2015     7            1.0                    1.0       139  2.679906
# 93     2016     4            1.0                    1.0       118  2.280526
# 94     2016     6            1.0                    1.0       113  4.442941
# 105    2017     7            1.0                    1.0       119  3.023687
# 111    2013     6            1.0                    1.0       193  2.081977
# 133    2013    11            1.0                    1.0       109  2.864090
# 138    2011    11            1.0                    1.0       135  2.034449
# 151    2012     2            1.0                    1.0       141  1.480795
# 154    2015     1            1.0                    1.0       122  3.103660
# 159    2017    12            1.0                    1.0        84  3.511286
# 181    2015     6            1.0                    1.0       112  2.446201
# 194    2011    10            1.0                    1.0       128  2.765315
# 204    2014    11            1.0                    1.0        99  7.109586
# 257    2017     8            1.0                    1.0       116  6.029339
# 262    2014     3            1.0                    1.0       119  0.696627
# 274    2017    11            1.0                    1.0        77  4.527855
# 297    2011    11            1.0                    1.0       114  2.537791
# 309    2010    12            1.0                    1.0       107  0.524636
# 402    2013    11            1.0                    1.0        87  1.556527
# 423    2017     2            1.0                    1.0       142  1.579817
# 431    2011     7            1.0                    1.0       113  2.249977
# 436    2016     8            1.0                    1.0        97  2.921181
# 441    2012    11            1.0                    1.0       109  0.560929
# 444    2010    12            1.0                    1.0       179  1.072429
# 449    2014     4            1.0                    1.0       131  3.389321
# 468    2015     9            1.0                    1.0        76  5.651882
# 477    2014    10            1.0                    1.0        98  4.990329
# ...     ...   ...            ...                    ...       ...       ...
# 49454  2013     3            1.0                    1.0        84  1.538239
# 49468  2016     1            1.0                    1.0       238  5.613759
# 49482  2013     9            1.0                    1.0        66  2.318325
# 49483  2017     7            1.0                    1.0        84  5.902612
# 49484  2016     6            1.0                    1.0       128  5.950603
# 49521  2012     9            1.0                    1.0        84  2.483771
# 49546  2014    11            1.0                    1.0       108  3.376310
# 49594  2016     1            1.0                    1.0        77  3.543088
# 49620  2012     8            1.0                    1.0        82  2.216050
# 49634  2016     9            1.0                    1.0       175  4.578572
# 49639  2014     2            1.0                    1.0       122  1.533284
# 49692  2015     2            1.0                    1.0       126  5.616170
# 49697  2016     8            1.0                    1.0        61  3.636559
# 49700  2012    10            1.0                    1.0       119  2.760743
# 49704  2017    10            1.0                    1.0       107  5.671095
# 49714  2017     7            1.0                    1.0       184  5.678645
# 49715  2015     5            1.0                    1.0       132  7.723846
# 49781  2014    11            1.0                    1.0       236  4.092691
# 49802  2011    11            0.5                    0.5       201  5.585475
# 49809  2014     5            1.0                    1.0       116  2.998038
# 49817  2011     9            1.0                    1.0       126  2.430123
# 49822  2016     9            1.0                    1.0       251  2.609272
# 49840  2012     3            1.0                    1.0        92  6.064904
# 49856  2014     4            1.0                    1.0       108  4.636895
# 49868  2011    12            1.0                    1.0       128  2.146255
# 49902  2014     2            1.0                    1.0        59  5.775070
# 49930  2013     4            1.0                    1.0        95  2.254011
# 49951  2015    11            1.0                    1.0        85  5.853167
# 49977  2017    11            1.0                    1.0        65  1.871237
# 49978  2013    10            1.0                    1.0       127  2.728633
#
#       FLESCH_SCORE HAS_TAGS
# 12       81.595455        0
# 27       78.561767        0
# 79       84.092500        0
# 87       63.512406        1
# 93       81.123506        1
# 94       79.321429        1
# 105      74.900769        1
# 111      69.107155        0
# 133      84.345075        0
# 138      73.620978        0
# 151      74.593750        0
# 154      75.207841        1
# 159      79.238300        1
# 181      71.459957        1
# 194      74.300842        0
# 204      76.234211        0
# 257      84.765987        1
# 262      75.863864        0
# 274      82.263375        1
# 297      72.565179        0
# 309      78.056193        0
# 402      73.367632        0
# 423      80.231160        1
# 431      80.628411        0
# 436      81.877500        1
# 441      75.466786        0
# 444      85.791526        0
# 449      69.826831        0
# 468      79.091500        1
# 477      79.862584        1
# ...            ...      ...
# 49454    78.997286        1
# 49468    70.823494        1
# 49482    72.389597        0
# 49483    80.828024        1
# 49484    78.626825        1
# 49521    85.728675        0
# 49546    77.920833        1
# 49594    83.775702        1
# 49620    97.885584        0
# 49634    78.850786        1
# 49639    75.177377        0
# 49692    80.177987        1
# 49697    86.274951        1
# 49700    69.368636        0
# 49704    81.227143        1
# 49714    76.336725        1
# 49715    64.161935        0
# 49781    79.349105        1
# 49802    69.436605        0
# 49809    86.460338        0
# 49817    81.041554        0
# 49822    69.743920        1
# 49840    81.267727        0
# 49856    80.274517        1
# 49868    76.807295        0
# 49902    86.443997        0
# 49930    76.761189        1
# 49951    81.457195        1
# 49977    78.810000        1
# 49978    78.732273        0
#
# [3227 rows x 36 columns]

# %%
ax = sns.barplot(x='YEAR', y='DAYS_TO_FUND',
                 data=Kiva_Phil, 
                 hue='PRIMARY_GENDER', 
                 palette='RdBu')
ax.set(xlabel = 'Year', ylabel= 'Days to funded', title='Mean days to funded for Philippines loans by gender')
plt.savefig('philippines_gender.png', dpi=300)

# %%
Kiva_Kenya = kiva2[kiva2['COUNTRY_NAME']=='Kenya']

# %%
#Kiva_Kenya.drop(['LOAN_ID', 'LOAN_AMOUNT', 'LOG_FUNDED'],axis=1).groupby(['YEAR','PRIMARY_GENDER']).mean()

# %%
#Kiva_Kenya.columns

# %%
#mean_by_gender = Kiva_Kenya.drop(['LOAN_ID','IMAGE_ID','LENDER_TERM', 'PARTNER_ID','LOAN_AMOUNT','LOG_FUNDED',
#                                  'FEMALE_BORROWERS','MALE_BORROWERS', 'PERCENT_FEMALE','PRIMARY_GENDER'],
#                                 axis=1).groupby(['PERCENT_FEMALE_GROUPED','YEAR']).mean()

# %%
#mean_by_gender

# %%
ax.legend(['Males', 'Females'])
ax = sns.barplot(x='YEAR', y='DAYS_TO_FUND',
                 data=Kiva_Kenya, 
                 hue='PRIMARY_GENDER', 
                 palette='RdBu_r')
ax.set(xlabel = 'Year', ylabel= 'Days to funded', title='Mean days to funded for Kenya loans by gender')
#ax.legend(loc='upper left')
#ax.get_legend_handles_labels(labels['Males', 'Females'])
plt.savefig('kenya_gender.png', dpi=300)

# %%
Kiva_Kenya.columns
# Out:
# Index(['LOAN_ID', 'ORIGINAL_LANGUAGE', 'DESCRIPTION_TRANSLATED',
#        'FUNDED_AMOUNT', 'LOAN_AMOUNT', 'STATUS', 'IMAGE_ID', 'SECTOR_NAME',
#        'COUNTRY_NAME', 'TOWN_NAME', 'CURRENCY_POLICY', 'PARTNER_ID',
#        'POSTED_TIME', 'PLANNED_EXPIRATION_TIME', 'DISBURSE_TIME',
#        'RAISED_TIME', 'LENDER_TERM', 'TAGS', 'BORROWER_GENDERS',
#        'REPAYMENT_INTERVAL', 'DISTRIBUTION_MODEL', 'TIME_DELTA',
#        'DAYS_TO_FUND', 'LOG_FUNDED', 'FEMALE_BORROWERS', 'MALE_BORROWERS',
#        'BORROWERS_TOTAL', 'PRIMARY_GENDER', 'YEAR', 'Month', 'PERCENT_FEMALE',
#        'PERCENT_FEMALE_GROUPED', 'LEN_DESC', 'SQRT_DAYS', 'FLESCH_SCORE',
#        'HAS_TAGS'],
#       dtype='object')

# %%
Kiva_CV = Kiva_Kenya.drop(['ORIGINAL_LANGUAGE', 'DESCRIPTION_TRANSLATED', 'FUNDED_AMOUNT', 'STATUS', 'IMAGE_ID',
                           'TOWN_NAME','CURRENCY_POLICY','PARTNER_ID','POSTED_TIME',
                           'PLANNED_EXPIRATION_TIME','DISBURSE_TIME','RAISED_TIME','LENDER_TERM',
                           'TAGS','BORROWER_GENDERS','REPAYMENT_INTERVAL','DISTRIBUTION_MODEL',
                           'TIME_DELTA','FEMALE_BORROWERS','MALE_BORROWERS','YEAR','PERCENT_FEMALE',
                           'PRIMARY_GENDER', 'COUNTRY_NAME'],
                          axis=1)

# %%
Kiva_CV.columns
# Out:
# Index(['LOAN_ID', 'LOAN_AMOUNT', 'SECTOR_NAME', 'DAYS_TO_FUND', 'LOG_FUNDED',
#        'BORROWERS_TOTAL', 'Month', 'PERCENT_FEMALE_GROUPED', 'LEN_DESC',
#        'SQRT_DAYS', 'FLESCH_SCORE'],
#       dtype='object')

# %%
Kiva_CV = Kiva_CV[Kiva_CV['FLESCH_SCORE'].isnull() == False]

# %% [markdown]
# # Stats Go Here

# %% [markdown]
# ## Create X/Y

# %%
#sns.pairplot(Kiva_CV)

# %%
y = Kiva_CV['SQRT_DAYS']
X = Kiva_CV.drop(['SQRT_DAYS', 'SECTOR_NAME', 'LOAN_ID', 'DAYS_TO_FUND', 'LOAN_AMOUNT', 'LEN_DESC'],1)

# %%
Dummy = patsy.dmatrix('SECTOR_NAME', data=Kiva_CV, return_type='dataframe')
#Dummy_2 = patsy.dmatrix('COUNTRY_NAME', data=X, return_type='dataframe')

# %%
X = X.join(Dummy)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3)

# %%
X.columns
# Out:
# Index(['LOG_FUNDED', 'BORROWERS_TOTAL', 'Month', 'PERCENT_FEMALE_GROUPED',
#        'FLESCH_SCORE', 'HAS_TAGS', 'Intercept', 'SECTOR_NAME[T.Arts]',
#        'SECTOR_NAME[T.Clothing]', 'SECTOR_NAME[T.Construction]',
#        'SECTOR_NAME[T.Education]', 'SECTOR_NAME[T.Entertainment]',
#        'SECTOR_NAME[T.Food]', 'SECTOR_NAME[T.Health]',
#        'SECTOR_NAME[T.Housing]', 'SECTOR_NAME[T.Manufacturing]',
#        'SECTOR_NAME[T.Personal Use]', 'SECTOR_NAME[T.Retail]',
#        'SECTOR_NAME[T.Services]', 'SECTOR_NAME[T.Transportation]',
#        'SECTOR_NAME[T.Wholesale]'],
#       dtype='object')

# %%
model= LinearRegression()
model.fit(X_train,y_train)
print('LinearRegression training',model.score(X_train,y_train))
print('LinearRegression testing',model.score(X_test,y_test))

model.fit(X_train,y_train)
print('Train Test Split training', model.score(X_train,y_train))
print('Train Test Split testing', model.score(X_test,y_test))
reg = LinearRegression()

scores = cross_val_score(reg, X, y, cv=10, scoring='r2')
print('Cross Validation', np.mean(scores))
# Out:
# LinearRegression training 0.2758597910884233
# LinearRegression testing 0.26310207114889883
# Train Test Split training 0.2758597910884233
# Train Test Split testing 0.26310207114889883
# Cross Validation 0.2644827211083893

# %% [markdown]
# ## Polynomial Fit for Linear Regression

# %%
#create a 2 degree polynomial and run linear regression on training data.
degree = 2
est = make_pipeline(PolynomialFeatures(degree), LinearRegression())
est.fit(X_train,y_train)
est.score(X_train,y_train)
# Out:
# 0.35958837018319845

# %%
est.score(X_test, y_test)
# Out:
# 0.2987020687844871

# %%
poly = PolynomialFeatures(3)
df = pd.DataFrame(poly.fit_transform(X_train))
df.columns = poly.get_feature_names()

# %%
# def plot_approximation(est, ax, label=None):
#     """Plot the approximation of ``est`` on axis ``ax``. """
#     #ax.plot(x_plot, f(x_plot), label='ground truth', color='green')
#     #ax.scatter(X, y, s=100)
#     ax.plot(x_plot, est.predict(x_plot[:, np.newaxis]), color='red', label=label)
#     ax.set_ylim((-2, 2))
#     ax.set_xlim((0, 1))
#     ax.set_ylabel('y')
#     ax.set_xlabel('x')
#     ax.legend(loc='upper right',frameon=True)
# x_plot = np.linspace(0, 1, 100)

# %%
# fig, ax_rows = plt.subplots(5, 2, figsize=(15, 20))
# for degree in range(5):
#     est = make_pipeline(PolynomialFeatures(degree), LinearRegression())
#     est.fit(X, y)
#     # This sets the appropriate axis for each degree (KEEP)
#     ax_row_left, ax_row_right = ax_rows[degree//2]
#     if degree%2 == 0:
#         ax = ax_row_left
#     else:
#         ax = ax_row_right
#     plot_approximation(est, ax, label='degree=%d' % degree)

# %%
lm1 = smf.ols('SQRT_DAYS ~ LOG_FUNDED + SECTOR_NAME + BORROWERS_TOTAL + Month + PERCENT_FEMALE_GROUPED + HAS_TAGS + FLESCH_SCORE', data=Kiva_Kenya)
fit1 = lm1.fit()
fit1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SQRT_DAYS   R-squared:                       0.274
# Model:                            OLS   Adj. R-squared:                  0.270
# Method:                 Least Squares   F-statistic:                     83.67
# Date:                Tue, 24 Apr 2018   Prob (F-statistic):          1.38e-289
# Time:                        14:57:06   Log-Likelihood:                -7907.2
# No. Observations:                4463   AIC:                         1.586e+04
# Df Residuals:                    4442   BIC:                         1.599e+04
# Df Model:                          20
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                         0.4338      0.349      1.245      0.213      -0.249       1.117
# SECTOR_NAME[T.Arts]              -0.3509      0.314     -1.116      0.264      -0.967       0.266
# SECTOR_NAME[T.Clothing]           0.5552      0.091      6.082      0.000       0.376       0.734
# SECTOR_NAME[T.Construction]      -0.5208      0.184     -2.826      0.005      -0.882      -0.159
# SECTOR_NAME[T.Education]         -0.9823      0.165     -5.965      0.000      -1.305      -0.659
# SECTOR_NAME[T.Entertainment]     -0.9238      0.640     -1.444      0.149      -2.178       0.331
# SECTOR_NAME[T.Food]               0.0321      0.062      0.519      0.603      -0.089       0.153
# SECTOR_NAME[T.Health]            -0.8062      0.204     -3.962      0.000      -1.205      -0.407
# SECTOR_NAME[T.Housing]           -0.7219      0.245     -2.951      0.003      -1.202      -0.242
# SECTOR_NAME[T.Manufacturing]     -1.2148      0.226     -5.378      0.000      -1.658      -0.772
# SECTOR_NAME[T.Personal Use]      -0.6797      0.134     -5.058      0.000      -0.943      -0.416
# SECTOR_NAME[T.Retail]             0.3549      0.070      5.092      0.000       0.218       0.492
# SECTOR_NAME[T.Services]           0.0060      0.083      0.072      0.943      -0.157       0.169
# SECTOR_NAME[T.Transportation]     0.4027      0.140      2.882      0.004       0.129       0.677
# SECTOR_NAME[T.Wholesale]         -1.3293      0.640     -2.076      0.038      -2.585      -0.074
# LOG_FUNDED                        0.5010      0.036     13.940      0.000       0.431       0.571
# BORROWERS_TOTAL                   0.0135      0.009      1.441      0.150      -0.005       0.032
# Month                             0.0541      0.006      8.844      0.000       0.042       0.066
# PERCENT_FEMALE_GROUPED           -0.3614      0.053     -6.832      0.000      -0.465      -0.258
# HAS_TAGS                          1.2668      0.045     28.052      0.000       1.178       1.355
# FLESCH_SCORE                     -0.0098      0.003     -3.084      0.002      -0.016      -0.004
# ==============================================================================
# Omnibus:                      163.026   Durbin-Watson:                   1.927
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              181.860
# Skew:                           0.469   Prob(JB):                     3.23e-40
# Kurtosis:                       3.313   Cond. No.                     2.40e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.4e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
y_sm = Kiva_CV['SQRT_DAYS']
X_sm = Kiva_CV.drop(['SQRT_DAYS', 'LOAN_ID', 'DAYS_TO_FUND', 'LOAN_AMOUNT', 'LEN_DESC'],1)
y_sm_pat, X_sm_pat = patsy.dmatrices('SQRT_DAYS ~ LOG_FUNDED + BORROWERS_TOTAL + Month + PERCENT_FEMALE_GROUPED + FLESCH_SCORE + HAS_TAGS + SECTOR_NAME', data=Kiva_CV, return_type="dataframe")
X_smc=sm.add_constant(X_sm)
X_train_sm, X_test_sm, y_train_sm, y_test_sm = train_test_split(X_sm_pat, y_sm_pat, test_size=.3)

# %%
lm1 = sm.OLS(y_train_sm, X_train_sm)
fit1 = lm1.fit()
fit1.summary()
#y_pred = fit1.predict(X_test_sm)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SQRT_DAYS   R-squared:                       0.264
# Model:                            OLS   Adj. R-squared:                  0.259
# Method:                 Least Squares   F-statistic:                     55.64
# Date:                Tue, 24 Apr 2018   Prob (F-statistic):          3.03e-189
# Time:                        17:13:24   Log-Likelihood:                -5543.5
# No. Observations:                3124   AIC:                         1.113e+04
# Df Residuals:                    3103   BIC:                         1.126e+04
# Df Model:                          20
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                         0.6025      0.424      1.421      0.155      -0.229       1.434
# SECTOR_NAME[T.Arts]              -0.7322      0.435     -1.684      0.092      -1.585       0.120
# SECTOR_NAME[T.Clothing]           0.5920      0.110      5.367      0.000       0.376       0.808
# SECTOR_NAME[T.Construction]      -0.7354      0.236     -3.115      0.002      -1.198      -0.273
# SECTOR_NAME[T.Education]         -0.9072      0.198     -4.588      0.000      -1.295      -0.520
# SECTOR_NAME[T.Entertainment]     -1.3916      0.829     -1.678      0.093      -3.017       0.234
# SECTOR_NAME[T.Food]               0.0080      0.074      0.107      0.915      -0.137       0.153
# SECTOR_NAME[T.Health]            -0.6819      0.242     -2.816      0.005      -1.157      -0.207
# SECTOR_NAME[T.Housing]           -0.5231      0.291     -1.801      0.072      -1.093       0.047
# SECTOR_NAME[T.Manufacturing]     -1.2151      0.268     -4.528      0.000      -1.741      -0.689
# SECTOR_NAME[T.Personal Use]      -0.6658      0.164     -4.070      0.000      -0.987      -0.345
# SECTOR_NAME[T.Retail]             0.2809      0.084      3.331      0.001       0.116       0.446
# SECTOR_NAME[T.Services]          -0.0501      0.099     -0.507      0.612      -0.244       0.144
# SECTOR_NAME[T.Transportation]     0.2928      0.171      1.710      0.087      -0.043       0.628
# SECTOR_NAME[T.Wholesale]         -1.3758      0.644     -2.137      0.033      -2.638      -0.113
# LOG_FUNDED                        0.5031      0.044     11.476      0.000       0.417       0.589
# BORROWERS_TOTAL                   0.0045      0.011      0.412      0.680      -0.017       0.026
# Month                             0.0537      0.007      7.353      0.000       0.039       0.068
# PERCENT_FEMALE_GROUPED           -0.3772      0.064     -5.889      0.000      -0.503      -0.252
# FLESCH_SCORE                     -0.0112      0.004     -2.927      0.003      -0.019      -0.004
# HAS_TAGS                          1.2310      0.054     22.602      0.000       1.124       1.338
# ==============================================================================
# Omnibus:                      148.929   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              171.628
# Skew:                           0.538   Prob(JB):                     5.39e-38
# Kurtosis:                       3.400   Cond. No.                     2.58e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.58e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#fit1.params

# %%
plt.plot(y_pred)
plt.ylabel('Count')
plt.xlabel('Normalized residuals')
# Out:
# Text(0.5,0,'Normalized residuals')

# %%
sns.residplot()

# %% [markdown]
# ## Adjusted $R^2$ calculation
#
# r2_adj = 1 - ((sum((y_test-results.predict(X_test))**2.0)/(len(X_test) - len(results.params) - 1))
#                 /(sum((y_test - np.mean(y_test))**2.0)/(len(X_test) - 1)))    #compute the adjusted r2 in the test set

# %% [markdown]
# ## Ridge CV

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error

# %%
y_ridge = Kiva_CV['SQRT_DAYS']
X_ridge = Kiva_CV.drop(['SQRT_DAYS', 'SECTOR_NAME', 'LOAN_ID', 'DAYS_TO_FUND', 'LOAN_AMOUNT', 'LEN_DESC'],1)
Dummy_ridge = patsy.dmatrix('SECTOR_NAME', data=Kiva_CV, return_type='dataframe')
X_ridge = X_ridge.join(Dummy_ridge)
X_train_intermediate, X_test_ridge, y_train_intermediate, y_test_ridge = train_test_split(X_ridge, y_ridge, test_size=.3)
X_train_ridge, X_validation_ridge, y_train_ridge, y_validation_ridge = train_test_split(X_train_intermediate, y_train_intermediate, test_size=.3)

# %%
rcv = RidgeCV(cv=10)

# %% [markdown]
# ## START HERE TOMORROW

# %%
alphas = [0.001, 0.01, 0.1, 1, 10]
print('All errors are RMSE')
print('-'*76)
for alpha in alphas:
    # instantiate and fit model
    ridge = Ridge(alpha=alpha, fit_intercept=True)
    ridge.fit(X_train_ridge, y_train_ridge)
    # calculate errors
    new_train_error = mean_squared_error(y_train_ridge, ridge.predict(X_train_ridge))
    new_validation_error = mean_squared_error(y_validation_ridge, ridge.predict(X_validation_ridge))
    new_test_error = mean_squared_error(y_test_ridge, ridge.predict(X_test_ridge))
    # print errors as report
    print('alpha: {:7} | train error: {:5} | val error: {:6} | test error: {}'.
          format(alpha,
                 round(new_train_error,3),
                 round(new_validation_error,3),
                 round(new_test_error,3)))
# Out:
# All errors are RMSE
# ----------------------------------------------------------------------------
# alpha:   0.001 | train error: 2.045 | val error:  1.983 | test error: 2.051
# alpha:    0.01 | train error: 2.045 | val error:  1.983 | test error: 2.051
# alpha:     0.1 | train error: 2.045 | val error:  1.983 | test error: 2.051
# alpha:       1 | train error: 2.045 | val error:  1.984 | test error: 2.05
# alpha:      10 | train error: 2.051 | val error:  1.985 | test error: 2.047

# %%
rcv.fit(X_train,y_train)
rcv.score(X_train, y_train)
# Out:
# 0.2894923585441558

# %%
ridge = Ridge(alpha=1e-2)
ridge_coef = ridge.fit(X, y).coef_
_ = plt.plot(range(len(X.columns)), ridge_coef)
_ = plt.xticks(range(len(X.columns)), X.columns, rotation=90)
_ = plt.ylabel('Coefficients')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Lasso CV

# %%
from sklearn.linear_model import Lasso

# %%
y_lasso = Kiva_CV['SQRT_DAYS']
X_lasso = Kiva_CV.drop(['SQRT_DAYS', 'SECTOR_NAME', 'LOAN_ID', 'DAYS_TO_FUND', 'LOAN_AMOUNT', 'LEN_DESC'],1)
Dummy_lasso = patsy.dmatrix('SECTOR_NAME', data=Kiva_CV, return_type='dataframe')
X_lasso = X_lasso.join(Dummy_lasso)
X_train_lasso, X_test_lasso, y_train_lasso, y_test_lasso = train_test_split(X_lasso, y_lasso, test_size=.3)

# %%
#test 6 different alpha values for the dataset, choose alpha to use that produces lowest error.
alphas = [1e-4, 1e-3, 1e-2, 1e-1, 1, 1e1]
val_errors = []
for alpha in alphas:
    lasso = Lasso(alpha=alpha, fit_intercept=True, random_state=77)
    errors = np.sum(-cross_val_score(lasso, 
                                     X= X_train_lasso, 
                                     y= y_train_lasso, 
                                     scoring='neg_mean_squared_error', 
                                     cv=10, 
                                     n_jobs=-1))
    val_errors.append(np.sqrt(errors))
alpha_to_use = alphas[val_errors.index(min(val_errors))]

# %%
lasso = Lasso(alpha=alpha_to_use)
lasso_coef = lasso.fit(X, y).coef_
_ = plt.plot(range(len(X.columns)), lasso_coef)
_ = plt.xticks(range(len(X.columns)), X.columns, rotation=90)
_ = plt.ylabel('Coefficients')
plt.show()

# %%
degree = 2
est = make_pipeline(PolynomialFeatures(degree), Lasso(alpha=1e-3))
est.fit(X_train,y_train)
est.score(X_train,y_train)
est.score(X_test, y_test)
# Out:
# 0.3080915595648814

# %%
lcv = LassoCV(cv=10)

# %%
lcv.fit(X,y)
lcv.score(X_test,y_test)
# Out:
# 0.24074769240416583

# %%
sns.residplot(x='LOG_FUNDED', y='SQRT_DAYS', data=Kiva_Kenya)

# %%
sns.residplot(x='LOG_FUNDED', y='DAYS_TO_FUND', data=Kiva_Kenya)

# %%
plt.plot(fit1.resid)
plt.ylabel('Count')
plt.xlabel('Normalized residuals')
# Out:
# Text(0.5,0,'Normalized residuals')

# %%
lm1 = smf.ols('DAYS ~ LOAN_AMOUNT + BORROWERS_TOTAL + PRIMARY_GENDER + COUNTRY_NAME + SECTOR_NAME', data=kiva)
fit1 = lm1.fit()
fit1.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/patsy/compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35     try:
# ---> 36         return f(*args, **kwargs)
#      37     except Exception as e:
#
# /anaconda3/lib/python3.6/site-packages/patsy/eval.py in eval(self, expr, source_name, inner_namespace)
#     165         return eval(code, {}, VarLookupDict([inner_namespace]
# --> 166                                             + self._namespaces))
#     167
#
# <string> in <module>()
#
# NameError: name 'DAYS' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# <ipython-input-131-84de6264fb38> in <module>()
# ----> 1 lm1 = smf.ols('DAYS ~ LOAN_AMOUNT + BORROWERS_TOTAL + PRIMARY_GENDER + COUNTRY_NAME + SECTOR_NAME', data=kiva)
#       2 fit1 = lm1.fit()
#       3 fit1.summary()
#
# /anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     153
#     154         tmp = handle_formula_data(data, None, formula, depth=eval_env,
# --> 155                                   missing=missing)
#     156         ((endog, exog), missing_idx, design_info) = tmp
#     157
#
# /anaconda3/lib/python3.6/site-packages/statsmodels/formula/formulatools.py in handle_formula_data(Y, X, formula, depth, missing)
#      63         if data_util._is_using_pandas(Y, None):
#      64             result = dmatrices(formula, Y, depth, return_type='dataframe',
# ---> 65                                NA_action=na_action)
#      66         else:
#      67             result = dmatrices(formula, Y, depth, return_type='dataframe',
#
# /anaconda3/lib/python3.6/site-packages/patsy/highlevel.py in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     308     eval_env = EvalEnvironment.capture(eval_env, reference=1)
#     309     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
# --> 310                                       NA_action, return_type)
#     311     if lhs.shape[1] == 0:
#     312         raise PatsyError("model is missing required outcome variables")
#
# /anaconda3/lib/python3.6/site-packages/patsy/highlevel.py in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     163         return iter([data])
#     164     design_infos = _try_incr_builders(formula_like, data_iter_maker, eval_env,
# --> 165                                       NA_action)
#     166     if design_infos is not None:
#     167         return build_design_matrices(design_infos, data,
#
# /anaconda3/lib/python3.6/site-packages/patsy/highlevel.py in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      68                                       data_iter_maker,
#      69                                       eval_env,
# ---> 70                                       NA_action)
#      71     else:
#      72         return None
#
# /anaconda3/lib/python3.6/site-packages/patsy/build.py in design_matrix_builders(termlists, data_iter_maker, eval_env, NA_action)
#     694                                                    factor_states,
#     695                                                    data_iter_maker,
# --> 696                                                    NA_action)
#     697     # Now we need the factor infos, which encapsulate the knowledge of
#     698     # how to turn any given factor into a chunk of data:
#
# /anaconda3/lib/python3.6/site-packages/patsy/build.py in _examine_factor_types(factors, factor_states, data_iter_maker, NA_action)
#     441     for data in data_iter_maker():
#     442         for factor in list(examine_needed):
# --> 443             value = factor.eval(factor_states[factor], data)
#     444             if factor in cat_sniffers or guess_categorical(value):
#     445                 if factor not in cat_sniffers:
#
# /anaconda3/lib/python3.6/site-packages/patsy/eval.py in eval(self, memorize_state, data)
#     564         return self._eval(memorize_state["eval_code"],
#     565                           memorize_state,
# --> 566                           data)
#     567
#     568     __getstate__ = no_pickling
#
# /anaconda3/lib/python3.6/site-packages/patsy/eval.py in _eval(self, code, memorize_state, data)
#     549                                  memorize_state["eval_env"].eval,
#     550                                  code,
# --> 551                                  inner_namespace=inner_namespace)
#     552
#     553     def memorize_chunk(self, state, which_pass, data):
#
# /anaconda3/lib/python3.6/site-packages/patsy/compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      41                                  origin)
#      42             # Use 'exec' to hide this syntax from the Python 2 parser:
# ---> 43             exec("raise new_exc from e")
#      44         else:
#      45             # In python 2, we just let the original exception escape -- better
#
# /anaconda3/lib/python3.6/site-packages/patsy/compat.py in <module>()
#
# PatsyError: Error evaluating factor: NameError: name 'DAYS' is not defined
#     DAYS ~ LOAN_AMOUNT + BORROWERS_TOTAL + PRIMARY_GENDER + COUNTRY_NAME + SECTOR_NAME
#     ^^^^

# %% [markdown]
# # Old Stuff

# %%
#create a plot of number of lenders vs total funded amount by year
#kenya_plot = sns.lmplot(x='DAYS' data=Kiva_Kenya, hue = 'PRIMARY_GENDER', col='YEAR', palette='coolwarm',
#          aspect=.6, size=8)
#axes = kenya_plot.axes
#axes[0,0].set_xlim(0,40)

# %%
#sns.jointplot(x='DAYS', y='PRIMARY_GENDER', data=Kiva_Kenya, kind='reg')

# %%
#create a new dataframe with no null values
kiva_no_null = kiva2.dropna()

# %%
kiva_no_null.drop(['LOAN_ID'], axis=1).groupby(['COUNTRY_NAME', 'SECTOR_NAME', 'STATUS','YEAR']).mean()

# %%
#create a plot of number of lenders vs total funded amount by year
lm = sns.lmplot(x='NUM_LENDERS_TOTAL', y='DAYS', data=kiva_no_null, col='YEAR', palette='coolwarm',
          aspect=.6, size=8)
axes = lm.axes
axes[0,0].set_xlim(0,300)

# %%
sns.jointplot(x='DAYS', y='DoW', data=kiva2, kind='scatter', alpha=.05)

# %%
sns.jointplot(x='DAYS', y='LOG_FUNDED', data=kiva2, kind='scatter', alpha=.2)

# %%
kiva2.info()

# %%
grouping = kiva2.drop(['LOAN_ID'], axis=1).groupby(['COUNTRY_NAME', 'SECTOR_NAME', 'STATUS','YEAR','NUM_LENDERS_TOTAL']).mean()

# %%
#lr =LinearRegression()

#X=kiva3[['FUNDED_AMOUNT','LENDER_TERM', 'NUM_LENDERS_TOTAL', 'FEMALE_BORROWERS', 'BORROWERS_TOTAL', 'DoW',]]
#y=kiva3['DAYS']

#lr.fit(X,y)

# %%
kiva3=kiva2.dropna()

# %%
lm1 = smf.ols('DAYS ~ FUNDED_AMOUNT + LENDER_TERM + NUM_LENDERS_TOTAL + FEMALE_BORROWERS + BORROWERS_TOTAL + DoW', data=kiva3)
fit1 = lm1.fit()
fit1.summary()

# %%
fig = plt.figure(figsize=(10,10))
fig = sm.graphics.plot_partregress_grid(fit1, fig=fig)
#plt.savefig('Partial_Regression.png', dpi=300)

# %%
X = patsy.dmatrix('COUNTRY_NAME',data=kiva3,return_type='dataframe')
X.head()

# %%
kiva_country = kiva3.join(X)

# %%
kiva3.info()

# %%
kiva_country.head

# %%
kiva_country.drop(['LOAN_NAME', 'LOAN_AMOUNT','ACTIVITY_NAME','COUNTRY_NAME','POSTED_TIME','DISBURSE_TIME','DISTRIBUTION_MODEL'], axis=1, inplace=True)

# %%
kiva_country.drop(['NUM_JOURNAL_ENTRIES','NUM_BULK_ENTRIES','BORROWER_GENDERS'], axis=1, inplace=True)

# %%
kiva_country.drop(['RAISED_TIME'], axis=1, inplace=True)

# %%
kiva_country.columns

# %%
kiva3.to_pickle('kiva3.pkl')`

# %%
kiva_country.to_pickle('kiva_country.pkl')

# %%
X= kiva_country.drop(['LOAN_ID', 'STATUS', 'SECTOR_NAME','REPAYMENT_INTERVAL','TIME_DELTA', "YEAR"],1)
y=kiva_country.DAYS

# %%
lr = LinearRegression()
# INSTRUCTOR NOTE: Run this multiple times to show the variation
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
# Fit the model against the training data
lr.fit(X_train, y_train)
# Evaluate the model against the testing data
lr.score(X_test, y_test)

# %%
lm2 = sm.OLS(y,X)
fit2 = lm2.fit()
fit2.summary()

# %%
fit2.resid.plot(style='o', figsize=(10,10), alpha=.05)

# %%
#sns.regplot(x=X, y=y, data=kiva3)

# %%
#fig = plt.figure(figsize=(10,10))
#sm.graphics.plot_partregress(y, X, kiva_country['YEAR'])

# %%
kiva3=kiva2.join(X)

# %%
p = lm1.fit().params

# %%
kiva3['YEAR'] = kiva3['POSTED_TIME'].dt.year

# %%
#Below here is exploratory data looking at things that did not receive funding. But not the direction I am going to go in.

# %%
#This creates a column with a 1 for a project primarily feature females and 0 for a project primarily featuring males
#kiva_no_NA['PRIMARY_GENDER'][(kiva_no_NA['FEMALE_BORROWERS'] - kiva_no_NA['MALE_BORROWERS'] >=0)] = 1
#kiva_no_NA['PRIMARY_GENDER'][((kiva_no_NA['FEMALE_BORROWERS'] - kiva_no_NA['MALE_BORROWERS']) <0)] = 0

# %%
#kiva_no_NA['PRIMARY_GENDER'].value_counts()

# %%
#kiva_not_funded = kiva3[(kiva3['DAYS'].isnull())]

# %%
#kiva_not_funded.head()

# %%
#kiva_not_funded['COUNTRY_NAME'].value_counts()

# %%
#kiva_not_funded['YEAR'] = kiva_not_funded['POSTED_TIME'].dt.year

# %%
#kiva_not_funded['YEAR'].value_counts()

# %%
#kiva3['SECTOR_NAME'].value_counts()

# %%
#percent_not_funded = kiva_not_funded['SECTOR_NAME'].value_counts() / kiva3['SECTOR_NAME'].value_counts()

# %%
#maybe something to look into more? is type of project an indicator in funding or not?
#percent_not_funded

# %%
#country_not_funded_percent = kiva_not_funded['COUNTRY_NAME'].value_counts() / kiva3['COUNTRY_NAME'].value_counts()

# %%
#Some countries have 100% not funded rate... but I also assume those countries have very few applications (1).
#I am sure this is something that needs a weighted measurement for prediction, but not sure how to capture it.
#Also this is just a small sample of 50k out of 1.4 million appplications total.
#country_not_funded_percent.dropna()

# %%
#year_not_funded_percent = kiva_not_funded['YEAR'].value_counts() / kiva3['YEAR'].value_counts()

# %%
#year_not_funded_percent

# %%
X=kiva2[['FUNDED_AMOUNT']]
y=kiva2.DAYS

# %%
X=sm.add_constant(X)

# %%
est = sm.OLS(y,X).fit()

# %%
xx1,xx2 = np.meshgrid(np.linspace(X.FUNDED_AMOUNT.min()))

# %%
lm1 = smf.ols('DAYS ~ FUNDED_AMOUNT + LENDER_TERM + NUM_LENDERS_TOTAL + FEMALE_BORROWERS + BORROWERS_TOTAL + DoW', data=kiva3)
fit1 = lm1.fit()
fit1.summary()

# %% [markdown]
# #Outdated, but keeping to have record of initial efforts
# ```Python
# df_agg = kiva2.groupby(['COUNTRY_NAME'])['SECTOR_NAME'].value_counts().unstack()
# df_agg.plot(kind='bar', stacked=True, figsize=(16,16))
# ```

# %% [markdown]
# #Old formatting, preserved for ability to look back at later.
# ```Python
#
# kiva.drop(['NUM_BULK_ENTRIES'], axis=1, inplace=True)
# kiva.drop(['DoW'], axis=1, inplace=True)
# kiva.drop(['NUM_JOURNAL_ENTRIES'], axis=1, inplace=True)
# kiva.drop(['ACTIVITY_NAME'], axis=1, inplace=True)
# kiva.drop(['DISBURSE_TIME'], axis=1, inplace=True)
# kiva.drop(['LOAN_NAME'], axis=1, inplace=True)
# kiva.drop(['LENDER_TERM'], axis=1, inplace=True)
# kiva.drop(['POSTED_TIME', 'RAISED_TIME','TIME_DELTA', 'REPAYMENT_INTERVAL'], axis=1, inplace=True)
#
# ```
